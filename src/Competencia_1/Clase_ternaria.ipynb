# %%
import numpy as np
import pandas as pd

# %%
# Escribir ruta de donde se encuentra dataset crudo
df_1 = pd.read_csv("/home/jorrin/Escritorio/Maestria DC/UBA_DMEyF_2024/UBA_DMEyF_2024/datasets/competencia_01_crudo.csv")

# %%
df_1.head()
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0          249221109    202101               1            0         0
# 1          249221468    202101               1            0         0
# 2          249223005    202101               1            0         0
# 3          249228180    202101               1            0         0
# 4          249232117    202101               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            61                 300        1664.94              17994.40
# 1            53                  37        4879.78              18640.95
# 2            48                 202        1828.35              37789.01
# 3            66                 320         175.87               2600.67
# 4            79                 373       16600.69              32270.07
#
#    mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  Visa_mpagado  \
# 0      1605.81  ...                    0.0                  4.0           0.0
# 1      1149.08  ...                    0.0                  4.0           0.0
# 2       610.12  ...                    0.0                  4.0           0.0
# 3       276.22  ...                    0.0                  4.0           0.0
# 4     16367.13  ...                    0.0                  4.0           0.0
#
#    Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  \
# 0         -37098.90                 0.0          7867.0           118514.88
# 1          -9864.93                 0.0          1124.0            31427.14
# 2         -32119.08                 0.0          3486.0              855.11
# 3         -10891.30                 0.0          8925.0             7517.73
# 4         -43610.75                 0.0          8607.0            37309.25
#
#    Visa_cconsumos  Visa_cadelantosefectivo  Visa_mpagominimo
# 0            10.0                      0.0          76538.25
# 1            14.0                      0.0              0.00
# 2             2.0                      0.0          19389.69
# 3             6.0                      0.0            516.12
# 4             5.0                      0.0           3084.99
#
# [5 rows x 154 columns]

# %%
df_ordenado = df_1.sort_values(by=['numero_de_cliente','foto_mes'])

# %%
df_ordenado.head(30)
# Out:
#         numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0               249221109    202101               1            0         0
# 162026          249221109    202102               1            0         0
# 324672          249221109    202103               1            0         0
# 488357          249221109    202104               1            0         0
# 652447          249221109    202105               1            0         0
# 817070          249221109    202106               1            0         0
# 1               249221468    202101               1            0         0
# 162027          249221468    202102               1            0         0
# 324673          249221468    202103               1            0         0
# 488358          249221468    202104               1            0         0
# 652448          249221468    202105               1            0         0
# 817071          249221468    202106               1            0         0
# 2               249223005    202101               1            0         0
# 162028          249223005    202102               1            0         0
# 324674          249223005    202103               1            0         0
# 488359          249223005    202104               1            0         0
# 652449          249223005    202105               1            0         0
# 817072          249223005    202106               1            0         0
# 3               249228180    202101               1            0         0
# 162029          249228180    202102               1            0         0
# 324675          249228180    202103               1            0         0
# 488360          249228180    202104               1            0         0
# 652450          249228180    202105               1            0         0
# 817073          249228180    202106               1            0         0
# 4               249232117    202101               1            0         0
# 162030          249232117    202102               1            0         0
# 324676          249232117    202103               1            0         0
# 488361          249232117    202104               1            0         0
# 652451          249232117    202105               1            0         0
# 817074          249232117    202106               1            0         0
#
#         cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0                 61                 300        1664.94              17994.40
# 162026            61                 301        1002.92              18337.34
# 324672            61                 302         769.74              18596.58
# 488357            62                 303        1532.79              19935.00
# 652447            62                 304        1804.14              20862.15
# 817070            62                 305         399.88              20332.88
# 1                 53                  37        4879.78              18640.95
# 162027            53                  38         739.04              12733.93
# 324673            53                  39       -1051.55              13816.08
# 488358            53                  40        3413.58              16311.12
# 652448            53                  41        4109.06              19556.54
# 817071            53                  42        4708.37              23227.25
# 2                 48                 202        1828.35              37789.01
# 162028            49                 203        2534.58              35177.81
# 324674            49                 204        2297.57              35985.11
# 488359            49                 205        2282.09              35034.77
# 652449            49                 206        2579.25              36403.66
# 817072            49                 207        3534.50              38207.62
# 3                 66                 320         175.87               2600.67
# 162029            66                 321          30.95               2752.73
# 324675            66                 322          -4.12               2546.75
# 488360            66                 323         214.11               2406.24
# 652450            66                 324         -22.75               2046.74
# 817073            66                 325        -138.82               1445.30
# 4                 79                 373       16600.69              32270.07
# 162030            79                 374        1752.98              33333.91
# 324676            79                 375        8775.23              39870.98
# 488361            80                 376         309.50              37935.46
# 652451            80                 377         264.98              37009.83
# 817074            80                 378         556.99              36468.62
#
#         mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  \
# 0           1605.81  ...                    0.0                  4.0
# 162026      1312.91  ...                    0.0                 -3.0
# 324672      1662.56  ...                    0.0                  1.0
# 488357      1899.52  ...                    0.0                  2.0
# 652447      2693.91  ...                    0.0                  5.0
# 817070      2115.35  ...                    0.0                  0.0
# 1           1149.08  ...                    0.0                  4.0
# 162027       814.14  ...                    0.0                 -3.0
# 324673      3453.98  ...                    0.0                  1.0
# 488358      4268.13  ...                    0.0                  2.0
# 652448      5381.40  ...                    0.0                  5.0
# 817071      5537.14  ...                    0.0                  0.0
# 2            610.12  ...                    0.0                  4.0
# 162028       381.17  ...                    0.0                 -3.0
# 324674       485.21  ...                    0.0                  1.0
# 488359       497.23  ...                    0.0                  2.0
# 652449       311.13  ...                    0.0                  5.0
# 817072       534.72  ...                    0.0                  0.0
# 3            276.22  ...                    0.0                  4.0
# 162029       160.05  ...                    0.0                 -3.0
# 324675       192.05  ...                    0.0                  1.0
# 488360       309.60  ...                    0.0                  2.0
# 652450       118.20  ...                    0.0                  5.0
# 817073       417.78  ...                    0.0                  0.0
# 4          16367.13  ...                    0.0                  4.0
# 162030      1669.74  ...                    0.0                 -3.0
# 324676      8849.25  ...                    0.0                  1.0
# 488361       467.17  ...                    0.0                  2.0
# 652451       466.32  ...                    0.0                  5.0
# 817074       484.57  ...                    0.0                  0.0
#
#         Visa_mpagado  Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  \
# 0                0.0         -37098.90                0.00          7867.0
# 162026           0.0        -126627.68             1219.19          7895.0
# 324672           0.0         -31388.56                0.00          7926.0
# 488357           0.0         -11773.53                0.00          7956.0
# 652447           0.0         -19480.30                0.00          7987.0
# 817070           0.0         -20783.64                0.00          8017.0
# 1                0.0          -9864.93                0.00          1124.0
# 162027           0.0              0.00                0.00          1152.0
# 324673           0.0         -39792.85                0.00          1183.0
# 488358           0.0         -85762.72                0.00          1213.0
# 652448           0.0        -118290.01                0.00          1244.0
# 817071           0.0        -124338.00                0.00          1274.0
# 2                0.0         -32119.08                0.00          3486.0
# 162028        9384.0         -19389.69                0.00          3514.0
# 324674           0.0         -58650.00                0.00          3545.0
# 488359           0.0         -23248.86                0.00          3575.0
# 652449           0.0         -38274.99                0.00          3606.0
# 817072           0.0         -28621.20                0.00          3636.0
# 3                0.0         -10891.30                0.00          8925.0
# 162029           0.0          -7741.80                0.00          8953.0
# 324675           0.0         -20499.34                0.00          8984.0
# 488360           0.0         -13620.87                0.00          9014.0
# 652450           0.0         -14024.38                0.00          9045.0
# 817073           0.0         -17595.00                0.00          9075.0
# 4                0.0         -43610.75                0.00          8607.0
# 162030           0.0         -41929.08                0.00          8635.0
# 324676           0.0         -49173.86                0.00          8666.0
# 488361           0.0         -49626.59                0.00          8696.0
# 652451           0.0         -45664.23                0.00          8727.0
# 817074           0.0         -48423.34                0.00          8757.0
#
#         Visa_mconsumototal  Visa_cconsumos  Visa_cadelantosefectivo  \
# 0                118514.88            10.0                      0.0
# 162026            28941.76            13.0                      0.0
# 324672             9564.73             9.0                      0.0
# 488357            18078.27            10.0                      0.0
# 652447            20336.57             9.0                      0.0
# 817070            16701.69             9.0                      0.0
# 1                 31427.14            14.0                      0.0
# 162027            41242.51            17.0                      0.0
# 324673            15550.67            14.0                      0.0
# 488358            27286.76            15.0                      0.0
# 652448            34269.85            10.0                      0.0
# 817071            81981.26            28.0                      0.0
# 2                   855.11             2.0                      0.0
# 162028             8616.58             8.0                      0.0
# 324674             1858.19             3.0                      0.0
# 488359            10845.47             8.0                      0.0
# 652449             2669.90             3.0                      0.0
# 817072             2669.90             3.0                      0.0
# 3                  7517.73             6.0                      0.0
# 162029            19908.19             8.0                      0.0
# 324675            13620.38             5.0                      0.0
# 488360            13608.00             6.0                      0.0
# 652450            15636.19             6.0                      0.0
# 817073            20496.15             6.0                      0.0
# 4                 37309.25             5.0                      0.0
# 162030            42366.56             9.0                      0.0
# 324676            44957.62             9.0                      0.0
# 488361            41042.26             6.0                      0.0
# 652451            43768.64             7.0                      0.0
# 817074            44938.95             7.0                      0.0
#
#         Visa_mpagominimo
# 0               76538.25
# 162026           2545.41
# 324672           1536.63
# 488357           1067.43
# 652447            199.41
# 817070           1313.76
# 1                   0.00
# 162027              0.00
# 324673              0.00
# 488358              0.00
# 652448              0.00
# 817071              0.00
# 2               19389.69
# 162028          20421.93
# 324674          12985.11
# 488359          19213.74
# 652449          18838.38
# 817072          18885.30
# 3                 516.12
# 162029           1384.14
# 324675            938.40
# 488360            985.32
# 652450           1337.22
# 817073           1818.15
# 4                3084.99
# 162030           3577.65
# 324676           3577.65
# 488361           3378.24
# 652451           3519.00
# 817074           4058.58
#
# [30 rows x 154 columns]

# %%
nclien_fmes=np.array(df_ordenado[['numero_de_cliente','foto_mes']])

# %%
nclien_fmes[1,1]
# Out:
# 202102

# %%
nclien_fmes[2,1]+1
# Out:
# 202104

# %%
def ternaria(x0,mes_final):
    
    clase_ternaria = []

    #agreguemos dos filas al final para poder correr el algoritmo
    x = np.concatenate([x0,np.array(((np.nan,np.nan),(np.nan,np.nan)))],axis=0)

    for i in range(len(x[:,0])-2):
        # Condicion clase baja+2
        if ((x[i,1] ==mes_final) or (x[i,1] ==mes_final-1)):
            clase_ternaria.append(np.nan)
            
        elif ((x[i,0] ==x[i+1,0]) and (x[i,1] ==(x[i+1,1]-1) )):
            if ((x[i,0] ==x[i+2,0]) and (x[i,1] ==(x[i+2,1]-2) )):
                clase = "CONTINUA"
                clase_ternaria.append(clase)
            else:
                clase = "BAJA+2"
                clase_ternaria.append(clase)
        else: 
            #Consideremos el caso raro como continua
            if((x[i,0] ==x[i+1,0]) and (x[i,1] ==(x[i+1,1]-2) )):
                #clase = "caso raro"
                clase = 'CONTINUA'
                clase_ternaria.append(clase)
            else:
                clase_ternaria.append('BAJA+1')

    return(clase_ternaria)

# %%
clases = ternaria(nclien_fmes,202106)

# %%
len(clases)
# Out:
# 981946

# %%
df_ordenado['clase_ternaria'] =np.array(clases)

# %%
df_ordenado[df_ordenado['foto_mes']==202103]['clase_ternaria'].value_counts()
# Out:
# CONTINUA    161684
# BAJA+1        1020
# BAJA+2         981
# Name: clase_ternaria, dtype: int64

# %%
df_ordenado.to_csv('competencia_01')

# %%
df_ordenado.columns
# Out:
# Index(['numero_de_cliente', 'foto_mes', 'active_quarter', 'cliente_vip',
#        'internet', 'cliente_edad', 'cliente_antiguedad', 'mrentabilidad',
#        'mrentabilidad_annual', 'mcomisiones',
#        ...
#        'Visa_fultimo_cierre', 'Visa_mpagado', 'Visa_mpagospesos',
#        'Visa_mpagosdolares', 'Visa_fechaalta', 'Visa_mconsumototal',
#        'Visa_cconsumos', 'Visa_cadelantosefectivo', 'Visa_mpagominimo',
#        'clase_ternaria'],
#       dtype='object', length=155)
